# %%
# Installation

# pip install tensorflow
# pip install Pillow
# pip install matplotlib
# pip install scikit-learn
# pip install seaborn
# pip install pydot

# Bibliothèques principales
import numpy as np
from pathlib import Path
import os
from PIL import Image
import shutil
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

# TensorFlow et Keras
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, callbacks
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.applications.mobilenet_v2 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import clone_model
from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import load_img

# Configuration GPU
try:
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"✅ GPU(s) détecté(s): {len(gpus)} - Croissance mémoire activée")
    else:
        print("⚠️  Aucun GPU détecté - Utilisation du CPU (entraînement sera lent)")
except Exception as e:
    print(f"Configuration GPU: {e}")


# Reproductibilité
tf.random.set_seed(55)
np.random.seed(55)    
SEED = 55

print(f"\n📦 Versions des bibliothèques :")
print(f"  - TensorFlow : {tf.__version__}")
print(f"  - Keras      : {keras.__version__}")
print(f"  - NumPy      : {np.__version__}")
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# ⚠️  Aucun GPU détecté - Utilisation du CPU (entraînement sera lent)
#
# 📦 Versions des bibliothèques :
#   - TensorFlow : 2.21.0
#   - Keras      : 3.13.2
#   - NumPy      : 2.4.3

# %% [markdown]
# ---------------------------------------------------------
# # Dataset
# ---------------------------------------------------------

# %%
# dataset

project_root = Path.cwd().parent
print("project_root : " + str(project_root))

data_dir = str(project_root) + "/CarDamageSeverityDataset"
data_dir = Path(data_dir)
print("data_dir:", data_dir)

IMG_SIZE = (224, 224)
# Out:
# project_root : c:\Users\huber_otpq54a\OneDrive\Documents\Formation\IA\Developpement\Projets\Deep_Learning
# data_dir: c:\Users\huber_otpq54a\OneDrive\Documents\Formation\IA\Developpement\Projets\Deep_Learning\CarDamageSeverityDataset

# %%
# Augmentation réelle du dataset

# CONFIG
INPUT_DIR = data_dir
OUTPUT_DIR = Path(str(project_root) + "/CarDamageSeverityDatasetAugmented")
AUG_PER_IMAGE = 5  # nombre d'images générées par image

# AUGMENTATION
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomTranslation(0.1, 0.1),
    layers.RandomBrightness(0.2),
])

# CRÉER DOSSIERS
os.makedirs(OUTPUT_DIR, exist_ok=True)

# TRAITEMENT
for class_name in os.listdir(INPUT_DIR):
    class_input_path = os.path.join(INPUT_DIR, class_name)
    class_output_path = os.path.join(OUTPUT_DIR, class_name)

    os.makedirs(class_output_path, exist_ok=True)

    for img_name in os.listdir(class_input_path):
        img_path = os.path.join(class_input_path, img_name)

        # Charger image
        img = Image.open(img_path).resize(IMG_SIZE)
        img_array = np.array(img)
        img_array = np.expand_dims(img_array, axis=0)  # batch dimension

        # Sauvegarder image originale (optionnel)
        base_name = os.path.splitext(img_name)[0]

        for i in range(AUG_PER_IMAGE):
            augmented = data_augmentation(img_array, training=True)

            # Convertir en image
            aug_img = augmented[0].numpy().astype("uint8")
            aug_img = Image.fromarray(aug_img)

            # Sauvegarde
            new_name = f"{base_name}_aug_{i}.jpg"
            aug_img.save(os.path.join(class_output_path, new_name))

print("Dataset augmenté créé ✅")

# %%
# Creation dataset complet : original + augmenté

data_dir_complet = str(project_root) + "/CarDamageSeverityDatasetComplet"
data_dir_complet = Path(data_dir_complet)
print("data_dir_complet :", data_dir_complet)

shutil.copytree(str(data_dir), str(data_dir_complet), dirs_exist_ok=True)   
shutil.copytree(str(OUTPUT_DIR), str(data_dir_complet), dirs_exist_ok=True)

# %%
# Analyse Dataset 

def analyse_dataset(p_chemin):

    # Explorer la structure
    print("\n📂 Structure du dataset : ", p_chemin)
    all_items = sorted([item.name for item in p_chemin.glob('*') if item.is_dir()])
    print(f"  - Tous les dossiers trouvés : {all_items}")

    class_names = all_items
    class_names = sorted(class_names)

    print(f"  - Nombre de classes : {len(class_names)}")

    if len(class_names) != 4:
        print("\n⚠️  Attention : Nombre de classes incorrect !")
        print("   Vérification du contenu du dataset...")

    # Compter les images par classe
    print("\n📊 Distribution des images par classe :")
    class_counts = {}
    total_images = 0
    for class_name in class_names:
        class_path = p_chemin / class_name
        count = len(list(class_path.glob('*.*')))
        class_counts[class_name] = count
        total_images += count
        print(f"  - {class_name:15s} : {count:4d} images")

    print(f"\n  - Total : {total_images} images")
    print(f"  - Moyenne par classe : {total_images / len(class_names):.0f} images")

    return class_names

class_names = analyse_dataset(data_dir)

# analyse_dataset(data_dir_complet)
# Out:
# 📂 Structure du dataset :  c:\Users\huber_otpq54a\OneDrive\Documents\Formation\IA\Developpement\Projets\Deep_Learning\CarDamageSeverityDataset
#   - Tous les dossiers trouvés : ['00-normal', '01-minor', '02-moderate', '03-severe']
#   - Nombre de classes : 4
#
# 📊 Distribution des images par classe :
#   - 00-normal       :  633 images
#   - 01-minor        :  550 images
#   - 02-moderate     :  552 images
#   - 03-severe       :  580 images
#
#   - Total : 2315 images
#   - Moyenne par classe : 579 images

# %%
#Préparation des datasets

# data_dir = data_dir_complet



# Paramètres
BATCH_SIZE = 32
VALIDATION_SPLIT = 0.2

# Créer le dataset d'entraînement avec filtrage des classes
train_ds = image_dataset_from_directory(
    data_dir,
    validation_split=VALIDATION_SPLIT,
    subset="training",
    seed=SEED,
    image_size=IMG_SIZE,       # redimensionne toutes les images automatiquement
    batch_size=BATCH_SIZE,     # nombre d’images envoyées au modèle à chaque itération
    label_mode='categorical',  # One-hot encoding pour multi-classe
    class_names=class_names
)

# for images, labels in train_ds:
#     print(images.shape, "   ", labels.shape)  # (32, 224, 224, 3)         (32, nb_classes)
    
# Créer le dataset de validation avec les mêmes classes
val_ds = image_dataset_from_directory(
    data_dir,
    validation_split=VALIDATION_SPLIT,
    subset="validation",
    seed=SEED,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    label_mode='categorical',
    class_names=class_names  # Même ordre de classes
)

print(f"\n  - Train batches  : {len(train_ds)}")
print(f"  - Val batches    : {len(val_ds)}")
print(f"  - Batch size     : {BATCH_SIZE}")
print(f"  - Image size     : {IMG_SIZE}")
print(f"\n  - Train samples  : ~{len(train_ds) * BATCH_SIZE}")
print(f"  - Val samples    : ~{len(val_ds) * BATCH_SIZE}")
# Out:
# Found 2315 files belonging to 4 classes.
# Using 1852 files for training.
# Found 2315 files belonging to 4 classes.
# Using 463 files for validation.
#
#   - Train batches  : 58
#   - Val batches    : 15
#   - Batch size     : 32
#   - Image size     : (224, 224)
#
#   - Train samples  : ~1856
#   - Val samples    : ~480

# %%
# Prétraitement et Data Augmentation

# Créer un modèle d'augmentation de données plus agressif
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.3),
    layers.RandomZoom(height_factor=0.2, width_factor=0.2),
    layers.RandomTranslation(height_factor=0.2, width_factor=0.2),
    layers.RandomContrast(0.2),
    layers.RandomBrightness(factor=0.2),
], name="data_augmentation")


# Fonction pour appliquer le prétraitement
def prepare_dataset(ds, augment=False, shuffle=True):
    # Normalisation MobileNetV2
    normalization = lambda x, y: (preprocess_input(x), y)
    ds = ds.map(normalization, num_parallel_calls=tf.data.AUTOTUNE)
    
    # Augmentation (seulement pour le train)
    if augment:
        augmentation = lambda x, y: (data_augmentation(x, training=True), y)
        ds = ds.map(augmentation, num_parallel_calls=tf.data.AUTOTUNE)
    
    # Shuffle pour le training
    if shuffle:
        ds = ds.shuffle(1000)
    
    # Optimisation des performances
    ds = ds.cache()  # Cache en mémoire
    ds = ds.prefetch(buffer_size=tf.data.AUTOTUNE)  # Prefetch pour accélérer
    
    return ds

# Appliquer le prétraitement
train_ds_prepared = prepare_dataset(train_ds, augment=False, shuffle=True)
val_ds_prepared = prepare_dataset(val_ds, augment=False, shuffle=False)

print(f"\n  - Train batches  : {len(train_ds_prepared)}")
print(f"  - Val batches    : {len(val_ds_prepared)}")
print(f"\n  - Train samples  : ~{len(train_ds_prepared) * BATCH_SIZE}")
print(f"  - Val samples    : ~{len(val_ds_prepared) * BATCH_SIZE}")
# Out:
#   - Train batches  : 58
#   - Val batches    : 15
#
#   - Train samples  : ~1856
#   - Val samples    : ~480

# %% [markdown]
# -------------------------------
# # Modèle
# -------------------------------

# %%
# Chargement MobileNetV2 pré-entraîné sans le classifier (include_top=False)
base_model = MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,  # Exclure la couche de classification ImageNet
    weights='imagenet',  # Charger les poids pré-entraînés sur ImageNet
    pooling='avg'  # Global Average Pooling à la fin
)

print("✅ Modèle MobileNetV2 chargé !\n")

# Afficher la structure du modèle
print("📋 Structure du modèle MobileNetV2 :")
print(f"  - Architecture   : MobileNetV2")
print(f"  - Input shape    : (224, 224, 3)")
print(f"  - Poids          : ImageNet (1000 classes)")
print(f"  - Output shape   : {base_model.output_shape}")
print(f"  - Nombre de couches : {len(base_model.layers)}")

# Compter les paramètres
total_params = base_model.count_params()
print(f"\n  - Nombre total de paramètres : {total_params:,}")
print(f"  - Taille en mémoire (approx.) : {total_params * 4 / (1024**2):.1f} MB")
# Out:
# ✅ Modèle MobileNetV2 chargé !
#
# 📋 Structure du modèle MobileNetV2 :
#   - Architecture   : MobileNetV2
#   - Input shape    : (224, 224, 3)
#   - Poids          : ImageNet (1000 classes)
#   - Output shape   : (None, 1280)
#   - Nombre de couches : 155
#
#   - Nombre total de paramètres : 2,257,984
#   - Taille en mémoire (approx.) : 8.6 MB

# %%
print("🔍 Aperçu des couches de MobileNetV2\n")
print("="*80)

# Fonction helper pour obtenir l'output shape
def get_output_shape(layer):
    try:
        if hasattr(layer, 'output_shape'):
            return str(layer.output_shape)
        elif hasattr(layer, 'output'):
            return str(layer.output.shape)
        else:
            return "N/A"
    except:
        return "N/A"

def affiche_couches(p_model):
    # Afficher les 15 premières et 15 dernières couches
    print("\n📌 Premières couches (extraction de features bas niveau) :")
    for i, layer in enumerate(p_model.layers[:15]):
        output_shape = get_output_shape(layer)
        print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

    print("\n      ...")

    print("\n📌 Dernières couches (features haut niveau) :")
    for i, layer in enumerate(p_model.layers[-15:], start=len(p_model.layers)-15):
        output_shape = get_output_shape(layer)
        print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")

    print("\n" + "="*80)

#affiche_couches(base_model)

def print_layers(p_model, n=0):
    for i, layer in enumerate(p_model.layers):
        # print(prefix + layer.name)
        output_shape = get_output_shape(layer)
        if n==0:
            print(f"  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")
        else:
            print(f"  {n:3d}.  {i+1:3d}. {layer.name:40s} | Output: {output_shape:30s} | Trainable: {layer.trainable}")
        if hasattr(layer, "layers"):  # modèle imbriqué
            x = i + 1
            print_layers(layer, x)

print_layers(base_model)
# Out:
# 🔍 Aperçu des couches de MobileNetV2
#
# ================================================================================
#     1. input_layer                              | Output: (None, 224, 224, 3)            | Trainable: True
#     2. Conv1                                    | Output: (None, 112, 112, 32)           | Trainable: True
#     3. bn_Conv1                                 | Output: (None, 112, 112, 32)           | Trainable: True
#     4. Conv1_relu                               | Output: (None, 112, 112, 32)           | Trainable: True
#     5. expanded_conv_depthwise                  | Output: (None, 112, 112, 32)           | Trainable: True
#     6. expanded_conv_depthwise_BN               | Output: (None, 112, 112, 32)           | Trainable: True
#     7. expanded_conv_depthwise_relu             | Output: (None, 112, 112, 32)           | Trainable: True
#     8. expanded_conv_project                    | Output: (None, 112, 112, 16)           | Trainable: True
#     9. expanded_conv_project_BN                 | Output: (None, 112, 112, 16)           | Trainable: True
#    10. block_1_expand                           | Output: (None, 112, 112, 96)           | Trainable: True
#    11. block_1_expand_BN                        | Output: (None, 112, 112, 96)           | Trainable: True
#    12. block_1_expand_relu                      | Output: (None, 112, 112, 96)           | Trainable: True
#    13. block_1_pad                              | Output: (None, 113, 113, 96)           | Trainable: True
#    14. block_1_depthwise                        | Output: (None, 56, 56, 96)             | Trainable: True
#    15. block_1_depthwise_BN                     | Output: (None, 56, 56, 96)             | Trainable: True
#    16. block_1_depthwise_relu                   | Output: (None, 56, 56, 96)             | Trainable: True
#    17. block_1_project                          | Output: (None, 56, 56, 24)             | Trainable: True
#    18. block_1_project_BN                       | Output: (None, 56, 56, 24)             | Trainable: True
#    19. block_2_expand                           | Output: (None, 56, 56, 144)            | Trainable: True
#    20. block_2_expand_BN                        | Output: (None, 56, 56, 144)            | Trainable: True
#    21. block_2_expand_relu                      | Output: (None, 56, 56, 144)            | Trainable: True
#    22. block_2_depthwise                        | Output: (None, 56, 56, 144)            | Trainable: True
#    23. block_2_depthwise_BN                     | Output: (None, 56, 56, 144)            | Trainable: True
#    24. block_2_depthwise_relu                   | Output: (None, 56, 56, 144)            | Trainable: True
#    25. block_2_project                          | Output: (None, 56, 56, 24)             | Trainable: True
#    26. block_2_project_BN                       | Output: (None, 56, 56, 24)             | Trainable: True
#    27. block_2_add                              | Output: (None, 56, 56, 24)             | Trainable: True
#    28. block_3_expand                           | Output: (None, 56, 56, 144)            | Trainable: True
#    29. block_3_expand_BN                        | Output: (None, 56, 56, 144)            | Trainable: True
#    30. block_3_expand_relu                      | Output: (None, 56, 56, 144)            | Trainable: True
#    31. block_3_pad                              | Output: (None, 57, 57, 144)            | Trainable: True
#    32. block_3_depthwise                        | Output: (None, 28, 28, 144)            | Trainable: True
#    33. block_3_depthwise_BN                     | Output: (None, 28, 28, 144)            | Trainable: True
#    34. block_3_depthwise_relu                   | Output: (None, 28, 28, 144)            | Trainable: True
#    35. block_3_project                          | Output: (None, 28, 28, 32)             | Trainable: True
#    36. block_3_project_BN                       | Output: (None, 28, 28, 32)             | Trainable: True
#    37. block_4_expand                           | Output: (None, 28, 28, 192)            | Trainable: True
#    38. block_4_expand_BN                        | Output: (None, 28, 28, 192)            | Trainable: True
#    39. block_4_expand_relu                      | Output: (None, 28, 28, 192)            | Trainable: True
#    40. block_4_depthwise                        | Output: (None, 28, 28, 192)            | Trainable: True
#    41. block_4_depthwise_BN                     | Output: (None, 28, 28, 192)            | Trainable: True
#    42. block_4_depthwise_relu                   | Output: (None, 28, 28, 192)            | Trainable: True
#    43. block_4_project                          | Output: (None, 28, 28, 32)             | Trainable: True
#    44. block_4_project_BN                       | Output: (None, 28, 28, 32)             | Trainable: True
#    45. block_4_add                              | Output: (None, 28, 28, 32)             | Trainable: True
#    46. block_5_expand                           | Output: (None, 28, 28, 192)            | Trainable: True
#    47. block_5_expand_BN                        | Output: (None, 28, 28, 192)            | Trainable: True
#    48. block_5_expand_relu                      | Output: (None, 28, 28, 192)            | Trainable: True
#    49. block_5_depthwise                        | Output: (None, 28, 28, 192)            | Trainable: True
#    50. block_5_depthwise_BN                     | Output: (None, 28, 28, 192)            | Trainable: True
#    51. block_5_depthwise_relu                   | Output: (None, 28, 28, 192)            | Trainable: True
#    52. block_5_project                          | Output: (None, 28, 28, 32)             | Trainable: True
#    53. block_5_project_BN                       | Output: (None, 28, 28, 32)             | Trainable: True
#    54. block_5_add                              | Output: (None, 28, 28, 32)             | Trainable: True
#    55. block_6_expand                           | Output: (None, 28, 28, 192)            | Trainable: True
#    56. block_6_expand_BN                        | Output: (None, 28, 28, 192)            | Trainable: True
#    57. block_6_expand_relu                      | Output: (None, 28, 28, 192)            | Trainable: True
#    58. block_6_pad                              | Output: (None, 29, 29, 192)            | Trainable: True
#    59. block_6_depthwise                        | Output: (None, 14, 14, 192)            | Trainable: True
#    60. block_6_depthwise_BN                     | Output: (None, 14, 14, 192)            | Trainable: True
#    61. block_6_depthwise_relu                   | Output: (None, 14, 14, 192)            | Trainable: True
#    62. block_6_project                          | Output: (None, 14, 14, 64)             | Trainable: True
#    63. block_6_project_BN                       | Output: (None, 14, 14, 64)             | Trainable: True
#    64. block_7_expand                           | Output: (None, 14, 14, 384)            | Trainable: True
#    65. block_7_expand_BN                        | Output: (None, 14, 14, 384)            | Trainable: True
#    66. block_7_expand_relu                      | Output: (None, 14, 14, 384)            | Trainable: True
#    67. block_7_depthwise                        | Output: (None, 14, 14, 384)            | Trainable: True
#    68. block_7_depthwise_BN                     | Output: (None, 14, 14, 384)            | Trainable: True
#    69. block_7_depthwise_relu                   | Output: (None, 14, 14, 384)            | Trainable: True
#    70. block_7_project                          | Output: (None, 14, 14, 64)             | Trainable: True
#    71. block_7_project_BN                       | Output: (None, 14, 14, 64)             | Trainable: True
#    72. block_7_add                              | Output: (None, 14, 14, 64)             | Trainable: True
#    73. block_8_expand                           | Output: (None, 14, 14, 384)            | Trainable: True
#    74. block_8_expand_BN                        | Output: (None, 14, 14, 384)            | Trainable: True
#    75. block_8_expand_relu                      | Output: (None, 14, 14, 384)            | Trainable: True
#    76. block_8_depthwise                        | Output: (None, 14, 14, 384)            | Trainable: True
#    77. block_8_depthwise_BN                     | Output: (None, 14, 14, 384)            | Trainable: True
#    78. block_8_depthwise_relu                   | Output: (None, 14, 14, 384)            | Trainable: True
#    79. block_8_project                          | Output: (None, 14, 14, 64)             | Trainable: True
#    80. block_8_project_BN                       | Output: (None, 14, 14, 64)             | Trainable: True
#    81. block_8_add                              | Output: (None, 14, 14, 64)             | Trainable: True
#    82. block_9_expand                           | Output: (None, 14, 14, 384)            | Trainable: True
#    83. block_9_expand_BN                        | Output: (None, 14, 14, 384)            | Trainable: True
#    84. block_9_expand_relu                      | Output: (None, 14, 14, 384)            | Trainable: True
#    85. block_9_depthwise                        | Output: (None, 14, 14, 384)            | Trainable: True
#    86. block_9_depthwise_BN                     | Output: (None, 14, 14, 384)            | Trainable: True
#    87. block_9_depthwise_relu                   | Output: (None, 14, 14, 384)            | Trainable: True
#    88. block_9_project                          | Output: (None, 14, 14, 64)             | Trainable: True
#    89. block_9_project_BN                       | Output: (None, 14, 14, 64)             | Trainable: True
#    90. block_9_add                              | Output: (None, 14, 14, 64)             | Trainable: True
#    91. block_10_expand                          | Output: (None, 14, 14, 384)            | Trainable: True
#    92. block_10_expand_BN                       | Output: (None, 14, 14, 384)            | Trainable: True
#    93. block_10_expand_relu                     | Output: (None, 14, 14, 384)            | Trainable: True
#    94. block_10_depthwise                       | Output: (None, 14, 14, 384)            | Trainable: True
#    95. block_10_depthwise_BN                    | Output: (None, 14, 14, 384)            | Trainable: True
#    96. block_10_depthwise_relu                  | Output: (None, 14, 14, 384)            | Trainable: True
#    97. block_10_project                         | Output: (None, 14, 14, 96)             | Trainable: True
#    98. block_10_project_BN                      | Output: (None, 14, 14, 96)             | Trainable: True
#    99. block_11_expand                          | Output: (None, 14, 14, 576)            | Trainable: True
#   100. block_11_expand_BN                       | Output: (None, 14, 14, 576)            | Trainable: True
#   101. block_11_expand_relu                     | Output: (None, 14, 14, 576)            | Trainable: True
#   102. block_11_depthwise                       | Output: (None, 14, 14, 576)            | Trainable: True
#   103. block_11_depthwise_BN                    | Output: (None, 14, 14, 576)            | Trainable: True
#   104. block_11_depthwise_relu                  | Output: (None, 14, 14, 576)            | Trainable: True
#   105. block_11_project                         | Output: (None, 14, 14, 96)             | Trainable: True
#   106. block_11_project_BN                      | Output: (None, 14, 14, 96)             | Trainable: True
#   107. block_11_add                             | Output: (None, 14, 14, 96)             | Trainable: True
#   108. block_12_expand                          | Output: (None, 14, 14, 576)            | Trainable: True
#   109. block_12_expand_BN                       | Output: (None, 14, 14, 576)            | Trainable: True
#   110. block_12_expand_relu                     | Output: (None, 14, 14, 576)            | Trainable: True
#   111. block_12_depthwise                       | Output: (None, 14, 14, 576)            | Trainable: True
#   112. block_12_depthwise_BN                    | Output: (None, 14, 14, 576)            | Trainable: True
#   113. block_12_depthwise_relu                  | Output: (None, 14, 14, 576)            | Trainable: True
#   114. block_12_project                         | Output: (None, 14, 14, 96)             | Trainable: True
#   115. block_12_project_BN                      | Output: (None, 14, 14, 96)             | Trainable: True
#   116. block_12_add                             | Output: (None, 14, 14, 96)             | Trainable: True
#   117. block_13_expand                          | Output: (None, 14, 14, 576)            | Trainable: True
#   118. block_13_expand_BN                       | Output: (None, 14, 14, 576)            | Trainable: True
#   119. block_13_expand_relu                     | Output: (None, 14, 14, 576)            | Trainable: True
#   120. block_13_pad                             | Output: (None, 15, 15, 576)            | Trainable: True
#   121. block_13_depthwise                       | Output: (None, 7, 7, 576)              | Trainable: True
#   122. block_13_depthwise_BN                    | Output: (None, 7, 7, 576)              | Trainable: True
#   123. block_13_depthwise_relu                  | Output: (None, 7, 7, 576)              | Trainable: True
#   124. block_13_project                         | Output: (None, 7, 7, 160)              | Trainable: True
#   125. block_13_project_BN                      | Output: (None, 7, 7, 160)              | Trainable: True
#   126. block_14_expand                          | Output: (None, 7, 7, 960)              | Trainable: True
#   127. block_14_expand_BN                       | Output: (None, 7, 7, 960)              | Trainable: True
#   128. block_14_expand_relu                     | Output: (None, 7, 7, 960)              | Trainable: True
#   129. block_14_depthwise                       | Output: (None, 7, 7, 960)              | Trainable: True
#   130. block_14_depthwise_BN                    | Output: (None, 7, 7, 960)              | Trainable: True
#   131. block_14_depthwise_relu                  | Output: (None, 7, 7, 960)              | Trainable: True
#   132. block_14_project                         | Output: (None, 7, 7, 160)              | Trainable: True
#   133. block_14_project_BN                      | Output: (None, 7, 7, 160)              | Trainable: True
#   134. block_14_add                             | Output: (None, 7, 7, 160)              | Trainable: True
#   135. block_15_expand                          | Output: (None, 7, 7, 960)              | Trainable: True
#   136. block_15_expand_BN                       | Output: (None, 7, 7, 960)              | Trainable: True
#   137. block_15_expand_relu                     | Output: (None, 7, 7, 960)              | Trainable: True
#   138. block_15_depthwise                       | Output: (None, 7, 7, 960)              | Trainable: True
#   139. block_15_depthwise_BN                    | Output: (None, 7, 7, 960)              | Trainable: True
#   140. block_15_depthwise_relu                  | Output: (None, 7, 7, 960)              | Trainable: True
#   141. block_15_project                         | Output: (None, 7, 7, 160)              | Trainable: True
#   142. block_15_project_BN                      | Output: (None, 7, 7, 160)              | Trainable: True
#   143. block_15_add                             | Output: (None, 7, 7, 160)              | Trainable: True
#   144. block_16_expand                          | Output: (None, 7, 7, 960)              | Trainable: True
#   145. block_16_expand_BN                       | Output: (None, 7, 7, 960)              | Trainable: True
#   146. block_16_expand_relu                     | Output: (None, 7, 7, 960)              | Trainable: True
#   147. block_16_depthwise                       | Output: (None, 7, 7, 960)              | Trainable: True
#   148. block_16_depthwise_BN                    | Output: (None, 7, 7, 960)              | Trainable: True
#   149. block_16_depthwise_relu                  | Output: (None, 7, 7, 960)              | Trainable: True
#   150. block_16_project                         | Output: (None, 7, 7, 320)              | Trainable: True
#   151. block_16_project_BN                      | Output: (None, 7, 7, 320)              | Trainable: True
#   152. Conv_1                                   | Output: (None, 7, 7, 1280)             | Trainable: True
#   153. Conv_1_bn                                | Output: (None, 7, 7, 1280)             | Trainable: True
#   154. out_relu                                 | Output: (None, 7, 7, 1280)             | Trainable: True
#   155. global_average_pooling2d                 | Output: (None, 1280)                   | Trainable: True

# %%
# Feature Extraction : Transfert-Learning

# Obtenir les noms de classes
class_names = train_ds.class_names
num_classes = len(class_names)
print(f"  - Classes        : {class_names}")
print(f"  - Nombre de classes : {num_classes}")

# Geler le modèle de base
base_model.trainable = False

# Architecture OPTIMALE pour ce dataset
inputs = keras.Input(shape=(224, 224, 3))
x = base_model(inputs, training=False)

# Classifier avec régularisation modérée
x = layers.Dropout(0.3)(x)  # Dropout modéré
x = layers.Dense(256, activation='relu', kernel_regularizer=keras.regularizers.l2(0.01))(x)
x = layers.Dropout(0.3)(x)
outputs = layers.Dense(num_classes, activation='softmax')(x)

model_frozen = keras.Model(inputs, outputs, name='MobileNetV2_Frozen')

# Compiler avec LR optimal
model_frozen.compile(
    optimizer=optimizers.Adam(learning_rate=0.001),  # LR standard
    loss='categorical_crossentropy',
    metrics=['accuracy', keras.metrics.TopKCategoricalAccuracy(k=2, name='top2_accuracy')]
)

print("\n✅ Modèle compilé !\n")

trainable = sum([tf.size(w).numpy() for w in model_frozen.trainable_weights])
non_trainable = sum([tf.size(w).numpy() for w in model_frozen.non_trainable_weights])
print(f"  - Paramètres entraînables    : {trainable:,}")
print(f"  - Paramètres non-entraînables: {non_trainable:,}")
print(f"  - Total                      : {trainable + non_trainable:,}")

model_frozen.summary()
# Out:
#   - Classes        : ['00-normal', '01-minor', '02-moderate', '03-severe']
#   - Nombre de classes : 4
#
# ✅ Modèle compilé !
#
#   - Paramètres entraînables    : 328,964
#   - Paramètres non-entraînables: 2,257,984
#   - Total                      : 2,586,948
# Model: "MobileNetV2_Frozen"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mobilenetv2_1.00_224            │ (None, 1280)           │     2,257,984 │
# │ (Functional)                    │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 1280)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │       327,936 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │         1,028 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,586,948 (9.87 MB)
#  Trainable params: 328,964 (1.25 MB)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %% [markdown]
# --------------------
# # Entraînement du modèle frozen
# --------------------

# %%
# Callbacks
early_stopping = callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=10,  # Patience raisonnable
    restore_best_weights=True,
    mode='max',
    verbose=1
)

reduce_lr = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=4,
    min_lr=1e-7,
    verbose=1
)

checkpoint = callbacks.ModelCheckpoint(
    'best_model_frozen.keras',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=0
)

EPOCHS_FROZEN = 30

history_frozen = model_frozen.fit(
    train_ds_prepared,
    validation_data=val_ds_prepared,
    epochs=EPOCHS_FROZEN,
    callbacks=[early_stopping, reduce_lr, checkpoint],
    verbose=1
)

print("\n✅ Entraînement frozen terminé !")
print(f"   Epochs effectués : {len(history_frozen.history['loss'])}")

best_val_acc = max(history_frozen.history['val_accuracy'])
best_epoch = history_frozen.history['val_accuracy'].index(best_val_acc) + 1
print(f"   Meilleure val_accuracy : {best_val_acc*100:.2f}% (epoch {best_epoch})")

if best_val_acc < 0.70:
    print(f"\n⚠️  Accuracy de {best_val_acc*100:.1f}% est en dessous de 70%")
    print("   Le modèle pourrait bénéficier de plus d'entraînement.")
elif best_val_acc < 0.80:
    print(f"\n✅ Bon résultat : {best_val_acc*100:.1f}%")
else:
    print(f"\n🎯 Excellent ! Accuracy de {best_val_acc*100:.1f}%")
# Out:
# Epoch 1/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 16s 222ms/step - accuracy: 0.5707 - loss: 4.3315 - top2_accuracy: 0.8056 - val_accuracy: 0.6220 - val_loss: 3.2160 - val_top2_accuracy: 0.8812 - learning_rate: 0.0010
# Epoch 2/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 12s 200ms/step - accuracy: 0.6825 - loss: 2.6045 - top2_accuracy: 0.8936 - val_accuracy: 0.6631 - val_loss: 2.2019 - val_top2_accuracy: 0.8963 - learning_rate: 0.0010
# Epoch 3/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 12s 199ms/step - accuracy: 0.7052 - loss: 1.8697 - top2_accuracy: 0.9114 - val_accuracy: 0.6847 - val_loss: 1.7001 - val_top2_accuracy: 0.8985 - learning_rate: 0.0010
# Epoch 4/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 12s 199ms/step - accuracy: 0.7165 - loss: 1.5057 - top2_accuracy: 0.9179 - val_accuracy: 0.6890 - val_loss: 1.4716 - val_top2_accuracy: 0.8963 - learning_rate: 0.0010
# Epoch 5/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 12s 200ms/step - accuracy: 0.7257 - loss: 1.2652 - top2_accuracy: 0.9212 - val_accuracy: 0.6933 - val_loss: 1.3038 - val_top2_accuracy: 0.9136 - learning_rate: 0.0010
# Epoch 6/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.7397 - loss: 1.1336 - top2_accuracy: 0.9179 - val_accuracy: 0.6631 - val_loss: 1.2187 - val_top2_accuracy: 0.9287 - learning_rate: 0.0010
# Epoch 7/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step - accuracy: 0.7403 - loss: 1.0177 - top2_accuracy: 0.9330 - val_accuracy: 0.6847 - val_loss: 1.1530 - val_top2_accuracy: 0.8898 - learning_rate: 0.0010
# Epoch 8/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 190ms/step - accuracy: 0.7576 - loss: 0.9469 - top2_accuracy: 0.9406 - val_accuracy: 0.6566 - val_loss: 1.0904 - val_top2_accuracy: 0.9114 - learning_rate: 0.0010
# Epoch 9/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.7597 - loss: 0.8896 - top2_accuracy: 0.9417 - val_accuracy: 0.6695 - val_loss: 1.0927 - val_top2_accuracy: 0.9006 - learning_rate: 0.0010
# Epoch 10/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.7786 - loss: 0.8439 - top2_accuracy: 0.9395 - val_accuracy: 0.6782 - val_loss: 1.0364 - val_top2_accuracy: 0.9071 - learning_rate: 0.0010
# Epoch 11/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.7457 - loss: 0.8590 - top2_accuracy: 0.9368 - val_accuracy: 0.6523 - val_loss: 1.0461 - val_top2_accuracy: 0.9093 - learning_rate: 0.0010
# Epoch 12/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.7462 - loss: 0.8519 - top2_accuracy: 0.9309 - val_accuracy: 0.6868 - val_loss: 1.0015 - val_top2_accuracy: 0.9136 - learning_rate: 0.0010
# Epoch 13/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.7651 - loss: 0.8404 - top2_accuracy: 0.9347 - val_accuracy: 0.6717 - val_loss: 1.0184 - val_top2_accuracy: 0.9006 - learning_rate: 0.0010
# Epoch 14/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 189ms/step - accuracy: 0.7711 - loss: 0.8187 - top2_accuracy: 0.9357 - val_accuracy: 0.6631 - val_loss: 0.9733 - val_top2_accuracy: 0.9222 - learning_rate: 0.0010
# Epoch 15/30
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 11s 190ms/step - accuracy: 0.7603 - loss: 0.8029 - top2_accuracy: 0.9390 - val_accuracy: 0.6868 - val_loss: 0.9563 - val_top2_accuracy: 0.9201 - learning_rate: 0.0010
# Epoch 15: early stopping
# Restoring model weights from the end of the best epoch: 5.
#
# ✅ Entraînement frozen terminé !
#    Epochs effectués : 15
#    Meilleure val_accuracy : 69.33% (epoch 5)
#
# ⚠️  Accuracy de 69.3% est en dessous de 70%
#    Le modèle pourrait bénéficier de plus d'entraînement.

# %%
def evaluation(p_history):
    # Epoch optimal (val_loss minimal)
    val_loss = p_history.history['val_loss']
    optimal_epoch = np.argmin(val_loss)
    optimal_val_loss = val_loss[optimal_epoch]
    print(f"Epoch optimal détecté : {optimal_epoch + 1} avec val_loss = {optimal_val_loss:.4f}")

    # Tracer loss et accuracy avec repère
    plt.figure(figsize=(14,5))

    # Loss
    plt.subplot(1,2,1)
    plt.plot(p_history.history['loss'], label='train loss')
    plt.plot(p_history.history['val_loss'], label='val loss')
    plt.axvline(optimal_epoch, color='r', linestyle='--', label=f'Optimal epoch ({optimal_epoch + 1})')
    plt.scatter(optimal_epoch, optimal_val_loss, color='red', s=100, zorder=5)
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Loss par epoch')
    plt.legend()

    # Accuracy
    plt.subplot(1,2,2)
    plt.plot(p_history.history['accuracy'], label='train acc')
    plt.plot(p_history.history['val_accuracy'], label='val acc')
    plt.axvline(optimal_epoch, color='r', linestyle='--', label=f'Optimal epoch ({optimal_epoch + 1})')
    plt.scatter(optimal_epoch, p_history.history['val_accuracy'][optimal_epoch], color='red', s=100, zorder=5)
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Accuracy par epoch')
    plt.legend()

    plt.show()

evaluation(history_frozen)
# Out:
# Epoch optimal détecté : 15 avec val_loss = 0.9563

# %%
# Matrice de confusion

def matrice_confusion(p_model, p_dataset):
    y_val = np.concatenate([y for x, y in p_dataset], axis=0)
    y_val = np.argmax(y_val, axis=1)
    y_pred_probs = p_model.predict(p_dataset)
    y_pred_classes = np.argmax(y_pred_probs, axis=1)

    cm = confusion_matrix(y_val, y_pred_classes)
    plt.figure(figsize=(6,5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()

    # Normalisation par ligne (chaque ligne = 100%)
    cm_norm = cm.astype('float') / cm.sum(axis=1, keepdims=True)

    # Conversion en pourcentage
    cm_percent = cm_norm * 100

    # Affichage
    plt.figure(figsize=(8,6))
    sns.heatmap(cm_percent, 
                annot=True, 
                fmt=".1f", 
                cmap="Blues")

    plt.xlabel('Prédictions')
    plt.ylabel('Vraies classes')
    plt.title('Matrice de confusion (%)')

    plt.show()

    # Rapport de classification
    print("\n📄 Rapport de classification détaillé :\n")
    print(classification_report(y_val, y_pred_classes, target_names=class_names, digits=3))


matrice_confusion(model_frozen, val_ds_prepared)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 181ms/step
# 📄 Rapport de classification détaillé :
#
#               precision    recall  f1-score   support
#
#    00-normal      0.794     0.962     0.870       104
#     01-minor      0.760     0.598     0.670       122
#  02-moderate      0.406     0.398     0.402        98
#    03-severe      0.752     0.784     0.768       139
#
#     accuracy                          0.693       463
#    macro avg      0.678     0.686     0.677       463
# weighted avg      0.690     0.693     0.687       463

# %% [markdown]
# --------------------------
# # Fine-Tuning
# --------------------------

# %%
# Évaluation AVANT fine-tuning
print("📈 Performance AVANT fine-tuning :")
results_before = model_frozen.evaluate(val_ds_prepared, verbose=0)
print(f"  - Accuracy : {results_before[1]*100:.2f}%")
print(f"  - Loss     : {results_before[0]:.4f}\n")

# clone du modèle avec ses poids
# model_finetuned = clone_model(model_frozen)
# model_finetuned.set_weights(model_frozen.get_weights())

# Dégeler le base_model
base_model.trainable = True

# Geler seulement les 100 premières couches
fine_tune_at = 100

for i, layer in enumerate(base_model.layers):
    if i < fine_tune_at:
        layer.trainable = False
    else:
        layer.trainable = True

print(f"📊 Configuration du dégel :")
print(f"  - Couches frozen  : {fine_tune_at}")
print(f"  - Couches unfrozen: {len(base_model.layers) - fine_tune_at}")

# Compter les paramètres
trainable_count = sum([tf.size(w).numpy() for w in model_frozen.trainable_weights])
non_trainable_count = sum([tf.size(w).numpy() for w in model_frozen.non_trainable_weights])
total = trainable_count + non_trainable_count

print(f"  - Paramètres entraînables : {trainable_count:,} ({trainable_count/total*100:.1f}%)")
print(f"  - Paramètres frozen       : {non_trainable_count:,}\n")

# Recompiler avec un LR très faible
FINE_TUNE_LR = 1e-5  # LR très faible

model_frozen.compile(
    optimizer=optimizers.Adam(learning_rate=FINE_TUNE_LR),
    loss='categorical_crossentropy',
    metrics=['accuracy', keras.metrics.TopKCategoricalAccuracy(k=2, name='top2_accuracy')]
)

# Le modèle fine-tuned est le modèle frozen modifié
model_finetuned = model_frozen

print_layers(model_finetuned)

print(f"✅ Modèle recompilé avec LR = {FINE_TUNE_LR}")
print("\n💡 Le modèle va continuer depuis les poids déjà appris.")

# Vérification immédiate
print("\n🔍 Vérification immédiate :")
results_after_compile = model_finetuned.evaluate(val_ds_prepared, verbose=0)
print(f"  - Accuracy : {results_after_compile[1]*100:.2f}%")
print(f"  - Loss     : {results_after_compile[0]:.4f}")

if abs(results_after_compile[1] - results_before[1]) < 0.01:
    print(f"\n  ✅ Parfait ! Les poids sont préservés ({results_after_compile[1]*100:.1f}%)")
else:
    print(f"\n  ⚠️  Les performances ont changé après recompilation")
# Out:
# 📈 Performance AVANT fine-tuning :
#   - Accuracy : 69.33%
#   - Loss     : 1.3038
#
# 📊 Configuration du dégel :
#   - Couches frozen  : 100
#   - Couches unfrozen: 55
#   - Paramètres entraînables : 2,190,404 (84.7%)
#   - Paramètres frozen       : 396,544
#
#     1. input_layer_1                            | Output: (None, 224, 224, 3)            | Trainable: True
#     2. mobilenetv2_1.00_224                     | Output: (None, 1280)                   | Trainable: True
#     2.    1. input_layer                              | Output: (None, 224, 224, 3)            | Trainable: False
#     2.    2. Conv1                                    | Output: (None, 112, 112, 32)           | Trainable: False
#     2.    3. bn_Conv1                                 | Output: (None, 112, 112, 32)           | Trainable: False
#     2.    4. Conv1_relu                               | Output: (None, 112, 112, 32)           | Trainable: False
#     2.    5. expanded_conv_depthwise                  | Output: (None, 112, 112, 32)           | Trainable: False
#     2.    6. expanded_conv_depthwise_BN               | Output: (None, 112, 112, 32)           | Trainable: False
#     2.    7. expanded_conv_depthwise_relu             | Output: (None, 112, 112, 32)           | Trainable: False
#     2.    8. expanded_conv_project                    | Output: (None, 112, 112, 16)           | Trainable: False
#     2.    9. expanded_conv_project_BN                 | Output: (None, 112, 112, 16)           | Trainable: False
#     2.   10. block_1_expand                           | Output: (None, 112, 112, 96)           | Trainable: False
#     2.   11. block_1_expand_BN                        | Output: (None, 112, 112, 96)           | Trainable: False
#     2.   12. block_1_expand_relu                      | Output: (None, 112, 112, 96)           | Trainable: False
#     2.   13. block_1_pad                              | Output: (None, 113, 113, 96)           | Trainable: False
#     2.   14. block_1_depthwise                        | Output: (None, 56, 56, 96)             | Trainable: False
#     2.   15. block_1_depthwise_BN                     | Output: (None, 56, 56, 96)             | Trainable: False
#     2.   16. block_1_depthwise_relu                   | Output: (None, 56, 56, 96)             | Trainable: False
#     2.   17. block_1_project                          | Output: (None, 56, 56, 24)             | Trainable: False
#     2.   18. block_1_project_BN                       | Output: (None, 56, 56, 24)             | Trainable: False
#     2.   19. block_2_expand                           | Output: (None, 56, 56, 144)            | Trainable: False
#     2.   20. block_2_expand_BN                        | Output: (None, 56, 56, 144)            | Trainable: False
#     2.   21. block_2_expand_relu                      | Output: (None, 56, 56, 144)            | Trainable: False
#     2.   22. block_2_depthwise                        | Output: (None, 56, 56, 144)            | Trainable: False
#     2.   23. block_2_depthwise_BN                     | Output: (None, 56, 56, 144)            | Trainable: False
#     2.   24. block_2_depthwise_relu                   | Output: (None, 56, 56, 144)            | Trainable: False
#     2.   25. block_2_project                          | Output: (None, 56, 56, 24)             | Trainable: False
#     2.   26. block_2_project_BN                       | Output: (None, 56, 56, 24)             | Trainable: False
#     2.   27. block_2_add                              | Output: (None, 56, 56, 24)             | Trainable: False
#     2.   28. block_3_expand                           | Output: (None, 56, 56, 144)            | Trainable: False
#     2.   29. block_3_expand_BN                        | Output: (None, 56, 56, 144)            | Trainable: False
#     2.   30. block_3_expand_relu                      | Output: (None, 56, 56, 144)            | Trainable: False
#     2.   31. block_3_pad                              | Output: (None, 57, 57, 144)            | Trainable: False
#     2.   32. block_3_depthwise                        | Output: (None, 28, 28, 144)            | Trainable: False
#     2.   33. block_3_depthwise_BN                     | Output: (None, 28, 28, 144)            | Trainable: False
#     2.   34. block_3_depthwise_relu                   | Output: (None, 28, 28, 144)            | Trainable: False
#     2.   35. block_3_project                          | Output: (None, 28, 28, 32)             | Trainable: False
#     2.   36. block_3_project_BN                       | Output: (None, 28, 28, 32)             | Trainable: False
#     2.   37. block_4_expand                           | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   38. block_4_expand_BN                        | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   39. block_4_expand_relu                      | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   40. block_4_depthwise                        | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   41. block_4_depthwise_BN                     | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   42. block_4_depthwise_relu                   | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   43. block_4_project                          | Output: (None, 28, 28, 32)             | Trainable: False
#     2.   44. block_4_project_BN                       | Output: (None, 28, 28, 32)             | Trainable: False
#     2.   45. block_4_add                              | Output: (None, 28, 28, 32)             | Trainable: False
#     2.   46. block_5_expand                           | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   47. block_5_expand_BN                        | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   48. block_5_expand_relu                      | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   49. block_5_depthwise                        | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   50. block_5_depthwise_BN                     | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   51. block_5_depthwise_relu                   | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   52. block_5_project                          | Output: (None, 28, 28, 32)             | Trainable: False
#     2.   53. block_5_project_BN                       | Output: (None, 28, 28, 32)             | Trainable: False
#     2.   54. block_5_add                              | Output: (None, 28, 28, 32)             | Trainable: False
#     2.   55. block_6_expand                           | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   56. block_6_expand_BN                        | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   57. block_6_expand_relu                      | Output: (None, 28, 28, 192)            | Trainable: False
#     2.   58. block_6_pad                              | Output: (None, 29, 29, 192)            | Trainable: False
#     2.   59. block_6_depthwise                        | Output: (None, 14, 14, 192)            | Trainable: False
#     2.   60. block_6_depthwise_BN                     | Output: (None, 14, 14, 192)            | Trainable: False
#     2.   61. block_6_depthwise_relu                   | Output: (None, 14, 14, 192)            | Trainable: False
#     2.   62. block_6_project                          | Output: (None, 14, 14, 64)             | Trainable: False
#     2.   63. block_6_project_BN                       | Output: (None, 14, 14, 64)             | Trainable: False
#     2.   64. block_7_expand                           | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   65. block_7_expand_BN                        | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   66. block_7_expand_relu                      | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   67. block_7_depthwise                        | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   68. block_7_depthwise_BN                     | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   69. block_7_depthwise_relu                   | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   70. block_7_project                          | Output: (None, 14, 14, 64)             | Trainable: False
#     2.   71. block_7_project_BN                       | Output: (None, 14, 14, 64)             | Trainable: False
#     2.   72. block_7_add                              | Output: (None, 14, 14, 64)             | Trainable: False
#     2.   73. block_8_expand                           | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   74. block_8_expand_BN                        | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   75. block_8_expand_relu                      | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   76. block_8_depthwise                        | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   77. block_8_depthwise_BN                     | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   78. block_8_depthwise_relu                   | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   79. block_8_project                          | Output: (None, 14, 14, 64)             | Trainable: False
#     2.   80. block_8_project_BN                       | Output: (None, 14, 14, 64)             | Trainable: False
#     2.   81. block_8_add                              | Output: (None, 14, 14, 64)             | Trainable: False
#     2.   82. block_9_expand                           | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   83. block_9_expand_BN                        | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   84. block_9_expand_relu                      | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   85. block_9_depthwise                        | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   86. block_9_depthwise_BN                     | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   87. block_9_depthwise_relu                   | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   88. block_9_project                          | Output: (None, 14, 14, 64)             | Trainable: False
#     2.   89. block_9_project_BN                       | Output: (None, 14, 14, 64)             | Trainable: False
#     2.   90. block_9_add                              | Output: (None, 14, 14, 64)             | Trainable: False
#     2.   91. block_10_expand                          | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   92. block_10_expand_BN                       | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   93. block_10_expand_relu                     | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   94. block_10_depthwise                       | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   95. block_10_depthwise_BN                    | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   96. block_10_depthwise_relu                  | Output: (None, 14, 14, 384)            | Trainable: False
#     2.   97. block_10_project                         | Output: (None, 14, 14, 96)             | Trainable: False
#     2.   98. block_10_project_BN                      | Output: (None, 14, 14, 96)             | Trainable: False
#     2.   99. block_11_expand                          | Output: (None, 14, 14, 576)            | Trainable: False
#     2.  100. block_11_expand_BN                       | Output: (None, 14, 14, 576)            | Trainable: False
#     2.  101. block_11_expand_relu                     | Output: (None, 14, 14, 576)            | Trainable: True
#     2.  102. block_11_depthwise                       | Output: (None, 14, 14, 576)            | Trainable: True
#     2.  103. block_11_depthwise_BN                    | Output: (None, 14, 14, 576)            | Trainable: True
#     2.  104. block_11_depthwise_relu                  | Output: (None, 14, 14, 576)            | Trainable: True
#     2.  105. block_11_project                         | Output: (None, 14, 14, 96)             | Trainable: True
#     2.  106. block_11_project_BN                      | Output: (None, 14, 14, 96)             | Trainable: True
#     2.  107. block_11_add                             | Output: (None, 14, 14, 96)             | Trainable: True
#     2.  108. block_12_expand                          | Output: (None, 14, 14, 576)            | Trainable: True
#     2.  109. block_12_expand_BN                       | Output: (None, 14, 14, 576)            | Trainable: True
#     2.  110. block_12_expand_relu                     | Output: (None, 14, 14, 576)            | Trainable: True
#     2.  111. block_12_depthwise                       | Output: (None, 14, 14, 576)            | Trainable: True
#     2.  112. block_12_depthwise_BN                    | Output: (None, 14, 14, 576)            | Trainable: True
#     2.  113. block_12_depthwise_relu                  | Output: (None, 14, 14, 576)            | Trainable: True
#     2.  114. block_12_project                         | Output: (None, 14, 14, 96)             | Trainable: True
#     2.  115. block_12_project_BN                      | Output: (None, 14, 14, 96)             | Trainable: True
#     2.  116. block_12_add                             | Output: (None, 14, 14, 96)             | Trainable: True
#     2.  117. block_13_expand                          | Output: (None, 14, 14, 576)            | Trainable: True
#     2.  118. block_13_expand_BN                       | Output: (None, 14, 14, 576)            | Trainable: True
#     2.  119. block_13_expand_relu                     | Output: (None, 14, 14, 576)            | Trainable: True
#     2.  120. block_13_pad                             | Output: (None, 15, 15, 576)            | Trainable: True
#     2.  121. block_13_depthwise                       | Output: (None, 7, 7, 576)              | Trainable: True
#     2.  122. block_13_depthwise_BN                    | Output: (None, 7, 7, 576)              | Trainable: True
#     2.  123. block_13_depthwise_relu                  | Output: (None, 7, 7, 576)              | Trainable: True
#     2.  124. block_13_project                         | Output: (None, 7, 7, 160)              | Trainable: True
#     2.  125. block_13_project_BN                      | Output: (None, 7, 7, 160)              | Trainable: True
#     2.  126. block_14_expand                          | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  127. block_14_expand_BN                       | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  128. block_14_expand_relu                     | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  129. block_14_depthwise                       | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  130. block_14_depthwise_BN                    | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  131. block_14_depthwise_relu                  | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  132. block_14_project                         | Output: (None, 7, 7, 160)              | Trainable: True
#     2.  133. block_14_project_BN                      | Output: (None, 7, 7, 160)              | Trainable: True
#     2.  134. block_14_add                             | Output: (None, 7, 7, 160)              | Trainable: True
#     2.  135. block_15_expand                          | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  136. block_15_expand_BN                       | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  137. block_15_expand_relu                     | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  138. block_15_depthwise                       | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  139. block_15_depthwise_BN                    | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  140. block_15_depthwise_relu                  | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  141. block_15_project                         | Output: (None, 7, 7, 160)              | Trainable: True
#     2.  142. block_15_project_BN                      | Output: (None, 7, 7, 160)              | Trainable: True
#     2.  143. block_15_add                             | Output: (None, 7, 7, 160)              | Trainable: True
#     2.  144. block_16_expand                          | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  145. block_16_expand_BN                       | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  146. block_16_expand_relu                     | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  147. block_16_depthwise                       | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  148. block_16_depthwise_BN                    | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  149. block_16_depthwise_relu                  | Output: (None, 7, 7, 960)              | Trainable: True
#     2.  150. block_16_project                         | Output: (None, 7, 7, 320)              | Trainable: True
#     2.  151. block_16_project_BN                      | Output: (None, 7, 7, 320)              | Trainable: True
#     2.  152. Conv_1                                   | Output: (None, 7, 7, 1280)             | Trainable: True
#     2.  153. Conv_1_bn                                | Output: (None, 7, 7, 1280)             | Trainable: True
#     2.  154. out_relu                                 | Output: (None, 7, 7, 1280)             | Trainable: True
#     2.  155. global_average_pooling2d                 | Output: (None, 1280)                   | Trainable: True
#     3. dropout                                  | Output: (None, 1280)                   | Trainable: True
#     4. dense                                    | Output: (None, 256)                    | Trainable: True
#     5. dropout_1                                | Output: (None, 256)                    | Trainable: True
#     6. dense_1                                  | Output: (None, 4)                      | Trainable: True
# ✅ Modèle recompilé avec LR = 1e-05
#
# 💡 Le modèle va continuer depuis les poids déjà appris.
#
# 🔍 Vérification immédiate :
#   - Accuracy : 69.33%
#   - Loss     : 1.3038
#
#   ✅ Parfait ! Les poids sont préservés (69.3%)

# %% [markdown]
# -------------------------------
# # Entraînement du modèle fine-tuned
# -------------------------------

# %%
print("🚀 Fine-tuning du modèle...\n")
print("⚠️  Le modèle continue depuis les poids frozen déjà entraînés\n")

# Callbacks pour fine-tuning
early_stopping_ft = callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=20,  # Beaucoup de patience
    restore_best_weights=True,
    mode='max',
    verbose=1
)

reduce_lr_ft = callbacks.ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=7,
    min_lr=1e-8,
    verbose=1
)

checkpoint_ft = callbacks.ModelCheckpoint(
    'best_model_finetuned.keras',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=0
)

# Entraînement
EPOCHS_FINETUNE = 50

print(f"Entraînement pour {EPOCHS_FINETUNE} epochs maximum...\n")

history_finetuned = model_finetuned.fit(
    train_ds_prepared,
    validation_data=val_ds_prepared,
    epochs=EPOCHS_FINETUNE,
    callbacks=[early_stopping_ft, reduce_lr_ft, checkpoint_ft],
    verbose=1
)

print("\n✅ Fine-tuning terminé !")
print(f"   Nombre d'epochs effectués : {len(history_finetuned.history['loss'])}")

# Meilleures performances
best_val_acc = max(history_finetuned.history['val_accuracy'])
best_epoch = history_finetuned.history['val_accuracy'].index(best_val_acc) + 1
print(f"   Meilleure val_accuracy : {best_val_acc*100:.2f}% (epoch {best_epoch})")

# Comparaison
frozen_best = max(history_frozen.history['val_accuracy'])
improvement = (best_val_acc - frozen_best) * 100
print(f"\n📊 Amélioration vs Frozen : {improvement:+.2f} points de pourcentage")
print(f"   - Frozen    : {frozen_best*100:.2f}%")
print(f"   - Fine-tuned: {best_val_acc*100:.2f}%")
# Out:
# 🚀 Fine-tuning du modèle...
#
# ⚠️  Le modèle continue depuis les poids frozen déjà entraînés
#
# Entraînement pour 50 epochs maximum...
#
# Epoch 1/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 23s 298ms/step - accuracy: 0.6485 - loss: 1.4333 - top2_accuracy: 0.8467 - val_accuracy: 0.6328 - val_loss: 1.5514 - val_top2_accuracy: 0.8553 - learning_rate: 1.0000e-05
# Epoch 2/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 287ms/step - accuracy: 0.7181 - loss: 1.2246 - top2_accuracy: 0.9136 - val_accuracy: 0.6048 - val_loss: 1.6337 - val_top2_accuracy: 0.8488 - learning_rate: 1.0000e-05
# Epoch 3/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 16s 278ms/step - accuracy: 0.7554 - loss: 1.1395 - top2_accuracy: 0.9379 - val_accuracy: 0.6220 - val_loss: 1.6144 - val_top2_accuracy: 0.8553 - learning_rate: 1.0000e-05
# Epoch 4/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 16s 281ms/step - accuracy: 0.7759 - loss: 1.0874 - top2_accuracy: 0.9455 - val_accuracy: 0.6242 - val_loss: 1.5865 - val_top2_accuracy: 0.8639 - learning_rate: 1.0000e-05
# Epoch 5/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 16s 279ms/step - accuracy: 0.7997 - loss: 1.0292 - top2_accuracy: 0.9590 - val_accuracy: 0.6285 - val_loss: 1.5779 - val_top2_accuracy: 0.8683 - learning_rate: 1.0000e-05
# Epoch 6/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 16s 281ms/step - accuracy: 0.8251 - loss: 0.9559 - top2_accuracy: 0.9714 - val_accuracy: 0.6479 - val_loss: 1.5394 - val_top2_accuracy: 0.8747 - learning_rate: 1.0000e-05
# Epoch 7/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 292ms/step - accuracy: 0.8423 - loss: 0.9165 - top2_accuracy: 0.9795 - val_accuracy: 0.6544 - val_loss: 1.5138 - val_top2_accuracy: 0.8790 - learning_rate: 1.0000e-05
# Epoch 8/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 286ms/step - accuracy: 0.8639 - loss: 0.8824 - top2_accuracy: 0.9833 - val_accuracy: 0.6523 - val_loss: 1.4998 - val_top2_accuracy: 0.8812 - learning_rate: 1.0000e-05
# Epoch 9/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 16s 283ms/step - accuracy: 0.8807 - loss: 0.8407 - top2_accuracy: 0.9827 - val_accuracy: 0.6566 - val_loss: 1.4631 - val_top2_accuracy: 0.8898 - learning_rate: 1.0000e-05
# Epoch 10/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 290ms/step - accuracy: 0.9028 - loss: 0.7862 - top2_accuracy: 0.9919 - val_accuracy: 0.6674 - val_loss: 1.4410 - val_top2_accuracy: 0.8855 - learning_rate: 1.0000e-05
# Epoch 11/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 294ms/step - accuracy: 0.9098 - loss: 0.7681 - top2_accuracy: 0.9924 - val_accuracy: 0.6760 - val_loss: 1.4057 - val_top2_accuracy: 0.8963 - learning_rate: 1.0000e-05
# Epoch 12/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 296ms/step - accuracy: 0.9347 - loss: 0.7252 - top2_accuracy: 0.9930 - val_accuracy: 0.6890 - val_loss: 1.3843 - val_top2_accuracy: 0.9050 - learning_rate: 1.0000e-05
# Epoch 13/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 286ms/step - accuracy: 0.9460 - loss: 0.6974 - top2_accuracy: 0.9968 - val_accuracy: 0.6868 - val_loss: 1.3735 - val_top2_accuracy: 0.9028 - learning_rate: 1.0000e-05
# Epoch 14/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 291ms/step - accuracy: 0.9563 - loss: 0.6647 - top2_accuracy: 0.9968 - val_accuracy: 0.6955 - val_loss: 1.3741 - val_top2_accuracy: 0.9028 - learning_rate: 1.0000e-05
# Epoch 15/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 298ms/step - accuracy: 0.9671 - loss: 0.6421 - top2_accuracy: 0.9984 - val_accuracy: 0.6976 - val_loss: 1.3638 - val_top2_accuracy: 0.9071 - learning_rate: 1.0000e-05
# Epoch 16/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 299ms/step - accuracy: 0.9725 - loss: 0.6172 - top2_accuracy: 0.9984 - val_accuracy: 0.6955 - val_loss: 1.3398 - val_top2_accuracy: 0.9071 - learning_rate: 1.0000e-05
# Epoch 17/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 300ms/step - accuracy: 0.9768 - loss: 0.5969 - top2_accuracy: 0.9989 - val_accuracy: 0.7019 - val_loss: 1.3211 - val_top2_accuracy: 0.9114 - learning_rate: 1.0000e-05
# Epoch 18/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 298ms/step - accuracy: 0.9833 - loss: 0.5805 - top2_accuracy: 0.9995 - val_accuracy: 0.7041 - val_loss: 1.3178 - val_top2_accuracy: 0.9136 - learning_rate: 1.0000e-05
# Epoch 19/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 303ms/step - accuracy: 0.9870 - loss: 0.5661 - top2_accuracy: 0.9995 - val_accuracy: 0.7171 - val_loss: 1.3012 - val_top2_accuracy: 0.9158 - learning_rate: 1.0000e-05
# Epoch 20/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 296ms/step - accuracy: 0.9919 - loss: 0.5469 - top2_accuracy: 1.0000 - val_accuracy: 0.7127 - val_loss: 1.3014 - val_top2_accuracy: 0.9158 - learning_rate: 1.0000e-05
# Epoch 21/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 292ms/step - accuracy: 0.9919 - loss: 0.5324 - top2_accuracy: 0.9989 - val_accuracy: 0.7106 - val_loss: 1.2933 - val_top2_accuracy: 0.9158 - learning_rate: 1.0000e-05
# Epoch 22/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 291ms/step - accuracy: 0.9962 - loss: 0.5223 - top2_accuracy: 1.0000 - val_accuracy: 0.7127 - val_loss: 1.2877 - val_top2_accuracy: 0.9201 - learning_rate: 1.0000e-05
# Epoch 23/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 300ms/step - accuracy: 0.9957 - loss: 0.5098 - top2_accuracy: 1.0000 - val_accuracy: 0.7171 - val_loss: 1.2908 - val_top2_accuracy: 0.9201 - learning_rate: 1.0000e-05
# Epoch 24/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 295ms/step - accuracy: 0.9968 - loss: 0.5010 - top2_accuracy: 1.0000 - val_accuracy: 0.7106 - val_loss: 1.2873 - val_top2_accuracy: 0.9179 - learning_rate: 1.0000e-05
# Epoch 25/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 307ms/step - accuracy: 0.9978 - loss: 0.4889 - top2_accuracy: 1.0000 - val_accuracy: 0.7084 - val_loss: 1.2791 - val_top2_accuracy: 0.9201 - learning_rate: 1.0000e-05
# Epoch 26/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 310ms/step - accuracy: 0.9984 - loss: 0.4823 - top2_accuracy: 1.0000 - val_accuracy: 0.7106 - val_loss: 1.2818 - val_top2_accuracy: 0.9244 - learning_rate: 1.0000e-05
# Epoch 27/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 307ms/step - accuracy: 1.0000 - loss: 0.4741 - top2_accuracy: 1.0000 - val_accuracy: 0.7106 - val_loss: 1.2889 - val_top2_accuracy: 0.9222 - learning_rate: 1.0000e-05
# Epoch 28/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 308ms/step - accuracy: 0.9995 - loss: 0.4653 - top2_accuracy: 1.0000 - val_accuracy: 0.7127 - val_loss: 1.2875 - val_top2_accuracy: 0.9287 - learning_rate: 1.0000e-05
# Epoch 29/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 312ms/step - accuracy: 1.0000 - loss: 0.4590 - top2_accuracy: 1.0000 - val_accuracy: 0.7149 - val_loss: 1.2981 - val_top2_accuracy: 0.9244 - learning_rate: 1.0000e-05
# Epoch 30/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 316ms/step - accuracy: 1.0000 - loss: 0.4504 - top2_accuracy: 1.0000 - val_accuracy: 0.7235 - val_loss: 1.3018 - val_top2_accuracy: 0.9244 - learning_rate: 1.0000e-05
# Epoch 31/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 302ms/step - accuracy: 0.9995 - loss: 0.4462 - top2_accuracy: 1.0000 - val_accuracy: 0.7235 - val_loss: 1.2952 - val_top2_accuracy: 0.9244 - learning_rate: 1.0000e-05
# Epoch 32/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 1.0000 - loss: 0.4387 - top2_accuracy: 1.0000
# Epoch 32: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 303ms/step - accuracy: 1.0000 - loss: 0.4381 - top2_accuracy: 1.0000 - val_accuracy: 0.7171 - val_loss: 1.2931 - val_top2_accuracy: 0.9287 - learning_rate: 1.0000e-05
# Epoch 33/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 295ms/step - accuracy: 1.0000 - loss: 0.4348 - top2_accuracy: 1.0000 - val_accuracy: 0.7192 - val_loss: 1.2915 - val_top2_accuracy: 0.9266 - learning_rate: 5.0000e-06
# Epoch 34/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 297ms/step - accuracy: 1.0000 - loss: 0.4321 - top2_accuracy: 1.0000 - val_accuracy: 0.7192 - val_loss: 1.2903 - val_top2_accuracy: 0.9244 - learning_rate: 5.0000e-06
# Epoch 35/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 300ms/step - accuracy: 1.0000 - loss: 0.4280 - top2_accuracy: 1.0000 - val_accuracy: 0.7214 - val_loss: 1.2903 - val_top2_accuracy: 0.9266 - learning_rate: 5.0000e-06
# Epoch 36/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 297ms/step - accuracy: 1.0000 - loss: 0.4255 - top2_accuracy: 1.0000 - val_accuracy: 0.7235 - val_loss: 1.2915 - val_top2_accuracy: 0.9266 - learning_rate: 5.0000e-06
# Epoch 37/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 294ms/step - accuracy: 1.0000 - loss: 0.4234 - top2_accuracy: 1.0000 - val_accuracy: 0.7235 - val_loss: 1.2904 - val_top2_accuracy: 0.9287 - learning_rate: 5.0000e-06
# Epoch 38/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 307ms/step - accuracy: 0.9995 - loss: 0.4207 - top2_accuracy: 1.0000 - val_accuracy: 0.7257 - val_loss: 1.2879 - val_top2_accuracy: 0.9266 - learning_rate: 5.0000e-06
# Epoch 39/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step - accuracy: 1.0000 - loss: 0.4168 - top2_accuracy: 1.0000
# Epoch 39: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 295ms/step - accuracy: 1.0000 - loss: 0.4172 - top2_accuracy: 1.0000 - val_accuracy: 0.7257 - val_loss: 1.2864 - val_top2_accuracy: 0.9309 - learning_rate: 5.0000e-06
# Epoch 40/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 297ms/step - accuracy: 1.0000 - loss: 0.4144 - top2_accuracy: 1.0000 - val_accuracy: 0.7257 - val_loss: 1.2851 - val_top2_accuracy: 0.9309 - learning_rate: 2.5000e-06
# Epoch 41/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 294ms/step - accuracy: 1.0000 - loss: 0.4143 - top2_accuracy: 1.0000 - val_accuracy: 0.7257 - val_loss: 1.2852 - val_top2_accuracy: 0.9352 - learning_rate: 2.5000e-06
# Epoch 42/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 18s 304ms/step - accuracy: 0.9995 - loss: 0.4127 - top2_accuracy: 1.0000 - val_accuracy: 0.7300 - val_loss: 1.2857 - val_top2_accuracy: 0.9330 - learning_rate: 2.5000e-06
# Epoch 43/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 297ms/step - accuracy: 1.0000 - loss: 0.4100 - top2_accuracy: 1.0000 - val_accuracy: 0.7279 - val_loss: 1.2843 - val_top2_accuracy: 0.9330 - learning_rate: 2.5000e-06
# Epoch 44/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 294ms/step - accuracy: 1.0000 - loss: 0.4103 - top2_accuracy: 1.0000 - val_accuracy: 0.7257 - val_loss: 1.2834 - val_top2_accuracy: 0.9352 - learning_rate: 2.5000e-06
# Epoch 45/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 300ms/step - accuracy: 1.0000 - loss: 0.4082 - top2_accuracy: 1.0000 - val_accuracy: 0.7235 - val_loss: 1.2827 - val_top2_accuracy: 0.9352 - learning_rate: 2.5000e-06
# Epoch 46/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 1.0000 - loss: 0.4048 - top2_accuracy: 1.0000
# Epoch 46: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 299ms/step - accuracy: 1.0000 - loss: 0.4054 - top2_accuracy: 1.0000 - val_accuracy: 0.7235 - val_loss: 1.2831 - val_top2_accuracy: 0.9352 - learning_rate: 2.5000e-06
# Epoch 47/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 297ms/step - accuracy: 1.0000 - loss: 0.4052 - top2_accuracy: 1.0000 - val_accuracy: 0.7235 - val_loss: 1.2819 - val_top2_accuracy: 0.9352 - learning_rate: 1.2500e-06
# Epoch 48/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 297ms/step - accuracy: 1.0000 - loss: 0.4043 - top2_accuracy: 1.0000 - val_accuracy: 0.7235 - val_loss: 1.2803 - val_top2_accuracy: 0.9352 - learning_rate: 1.2500e-06
# Epoch 49/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 294ms/step - accuracy: 1.0000 - loss: 0.4035 - top2_accuracy: 1.0000 - val_accuracy: 0.7235 - val_loss: 1.2791 - val_top2_accuracy: 0.9352 - learning_rate: 1.2500e-06
# Epoch 50/50
# 58/58 ━━━━━━━━━━━━━━━━━━━━ 17s 293ms/step - accuracy: 1.0000 - loss: 0.4018 - top2_accuracy: 1.0000 - val_accuracy: 0.7235 - val_loss: 1.2769 - val_top2_accuracy: 0.9330 - learning_rate: 1.2500e-06
# Restoring model weights from the end of the best epoch: 42.
#
# ✅ Fine-tuning terminé !
#    Nombre d'epochs effectués : 50
#    Meilleure val_accuracy : 73.00% (epoch 42)
#
# 📊 Amélioration vs Frozen : +3.67 points de pourcentage
#    - Frozen    : 69.33%
#    - Fine-tuned: 73.00%

# %%
evaluation(history_finetuned)
# Out:
# Epoch optimal détecté : 50 avec val_loss = 1.2769

# %%
matrice_confusion(model_finetuned, val_ds_prepared)
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 195ms/step
# 📄 Rapport de classification détaillé :
#
#               precision    recall  f1-score   support
#
#    00-normal      0.851     0.990     0.916       104
#     01-minor      0.817     0.730     0.771       122
#  02-moderate      0.455     0.459     0.457        98
#    03-severe      0.754     0.727     0.740       139
#
#     accuracy                          0.730       463
#    macro avg      0.719     0.726     0.721       463
# weighted avg      0.729     0.730     0.728       463

# %%
# Sauvegarde du modèle

# Sauvegarder au format Keras (.keras)
model_path = 'mobilenetv2_test1_finetuned.keras'
model_finetuned.save(model_path)

print(f"\n✅ Modèle sauvegardé : {model_path}")
print(f"   Taille du fichier : {os.path.getsize(model_path) / (1024**2):.1f} MB")

# Sauvegarder aussi au format h5 (legacy)
model_h5_path = 'mobilenetv2_test1_finetuned.h5'
model_finetuned.save(model_h5_path)
print(f"\n✅ Modèle également sauvegardé en .h5 : {model_h5_path}")


# Pour recharger le modèle
# loaded_model = keras.models.load_model(model_path)

# %% [markdown]
# ---------------------------------------
# # Test
# ---------------------------------------

# %%
# Fonction de prédiction

def predict_image(model, image_path, class_names):
    
    # Charger et prétraiter l'image
    img = load_img(image_path, target_size=(224, 224))
    img_array = tf.keras.preprocessing.image.img_to_array(img)
    img_array = tf.expand_dims(img_array, 0)  # Ajouter dimension batch
    img_array = preprocess_input(img_array)  # Normalisation MobileNetV2
    
    # Prédire
    predictions = model.predict(img_array, verbose=0)
    predicted_class_idx = np.argmax(predictions[0])
    confidence = predictions[0][predicted_class_idx]
    
    # Top 3 prédictions
    top3_idx = np.argsort(predictions[0])[-3:][::-1]
    
    return {
        'predicted_class': class_names[predicted_class_idx],
        'confidence': confidence,
        'all_probabilities': predictions[0],
        'top3': [(class_names[i], predictions[0][i]) for i in top3_idx]
    }

print("✅ Fonction de prédiction créée !")
# Out:
# ✅ Fonction de prédiction créée !

# %%
# Visualisation des probabilités pour une image

from PIL import Image

# Prendre une image spécifique
sample_image_path = "C:/Users/huber_otpq54a/OneDrive/Documents/Formation/IA/Developpement/Projets/Deep_Learning/Test/accident-de-voiture.webp"

im = Image.open(sample_image_path).convert("RGB")
sample_image_path = sample_image_path + ".jpg"
im.save(sample_image_path, "JPEG")

result = predict_image(model_finetuned, sample_image_path, class_names)

# Visualiser
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Image
img = plt.imread(sample_image_path)
axes[0].imshow(img)
axes[0].axis('off')
axes[0].set_title(f"Image : {str(Path(sample_image_path).name)}", fontsize=14, fontweight='bold')

# Probabilités
probs = result['all_probabilities'] * 100
colors = ['#2ecc71' if i == np.argmax(probs) else '#3498db' for i in range(len(probs))]

bars = axes[1].barh(class_names, probs, color=colors, edgecolor='black', linewidth=2)
axes[1].set_xlabel('Probabilité (%)', fontsize=13, fontweight='bold')
axes[1].set_title('Distribution des Probabilités', fontsize=14, fontweight='bold')
axes[1].grid(alpha=0.3, axis='x')

# Ajouter les valeurs
for bar, prob in zip(bars, probs):
    width = bar.get_width()
    axes[1].text(width + 1, bar.get_y() + bar.get_height()/2.,
                f'{prob:.1f}%',
                ha='left', va='center', fontsize=11, fontweight='bold')

plt.tight_layout()
plt.show()

print(f"\n🔍 Analyse de la prédiction :")
print(f"  - Classe prédite : {result['predicted_class']}")
print(f"  - Confiance      : {result['confidence']*100:.2f}%")
print(f"\n  - Top 3 prédictions :")
for i, (cls, prob) in enumerate(result['top3'], 1):
    print(f"    {i}. {cls:15s} : {prob*100:.2f}%")
# Out:
# 🔍 Analyse de la prédiction :
#   - Classe prédite : 02-moderate
#   - Confiance      : 63.10%
#
#   - Top 3 prédictions :
#     1. 02-moderate     : 63.10%
#     2. 01-minor        : 25.26%
#     3. 03-severe       : 11.25%
